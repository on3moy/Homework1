# %% [markdown]
# # Plot Notebook
# Contains a list of evenly spaced numbers over the range

# %%
# Imports libraries 
import matplotlib.pyplot as plt 
import numpy as np

# Changes style to ggplot
plt.style.use('ggplot')

# Plot sin wave using numpy and matplotlib
plt.plot(x,np.sin(x))
plt.show()
